# %%
import pandas as pd

# %%
data=pd.read_csv('data/data_trunc.csv',index_col=0)

# %%
data
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976       50.0        50.0        50.0      123.0        69.0
# 1       19.986       50.0        50.0        50.0      123.0        69.0
# 2       19.996       50.0        50.0        50.0      123.0        69.0
# 3       20.016       50.0        50.0        50.0      122.0        69.0
# 4       20.026       50.0        50.0        50.0      123.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717361  49.924       50.0        50.0        50.0       41.0        56.0
# 717362  49.934       50.0        50.0        50.0       41.0        56.0
# 717363  49.944       50.0        50.0        50.0       41.0        56.0
# 717364  49.954       50.0        50.0        50.0       41.0        56.0
# 717365  49.964       50.0        50.0        50.0       41.0        56.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  Vo_GFL_PU  SCL_SG_MVA  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717366 entries, 0 to 717365
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         717366 non-null  float64
#  1   Fre_SG_Hz    717366 non-null  float64
#  2   Fre_GFM_Hz   717366 non-null  float64
#  3   Fre_GFL_Hz   717366 non-null  float64
#  4   Po_SG_MVA    717366 non-null  float64
#  5   Po_GFM_MVA   717366 non-null  float64
#  6   Po_GFL_MVA   717366 non-null  float64
#  7   Total_MVA    717366 non-null  float64
#  8   Vo_SG_PU     717366 non-null  float64
#  9   Vo_GFM_PU    717366 non-null  float64
#  10  Vo_GFL_PU    717366 non-null  float64
#  11  SCL_SG_MVA   717366 non-null  float64
#  12  SCL_GFM_MVA  717366 non-null  float64
#  13  SCL_GFL_MVA  717366 non-null  float64
# dtypes: float64(14)
# memory usage: 82.1 MB

# %%
df=data[['Total_MVA', 'Po_GFM_MVA','Po_SG_MVA', 'Po_GFL_MVA']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717366 entries, 0 to 717365
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Total_MVA   717366 non-null  float64
#  1   Po_GFM_MVA  717366 non-null  float64
#  2   Po_SG_MVA   717366 non-null  float64
#  3   Po_GFL_MVA  717366 non-null  float64
# dtypes: float64(4)
# memory usage: 27.4 MB

# %%
df.describe()
# Out:
#            Total_MVA     Po_GFM_MVA      Po_SG_MVA     Po_GFL_MVA
# count  717366.000000  717366.000000  717366.000000  717366.000000
# mean      188.372732      48.445338      91.200956      48.714899
# std        13.831393      17.903333      21.844904      23.236615
# min       153.000000      10.000000      39.000000     -21.000000
# 25%       177.000000      35.000000      75.000000      45.000000
# 50%       184.000000      54.000000      94.000000      55.000000
# 75%       200.000000      63.000000     108.000000      63.000000
# max       232.000000      86.000000     150.000000      89.000000

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# 178.0    100570
# 177.0     89512
# 176.0     59500
# 185.0     33280
# 175.0     32456
#           ...
# 157.0         5
# 232.0         4
# 158.0         2
# 153.0         2
# 154.0         1
# Name: Total_MVA, Length: 80, dtype: int64
# 67.0    38309
# 68.0    36154
# 63.0    28819
# 60.0    28467
# 55.0    27506
#         ...
# 85.0      651
# 83.0      312
# 80.0      224
# 81.0      188
# 84.0       95
# Name: Po_GFM_MVA, Length: 77, dtype: int64
# 101.0    43084
# 94.0     39280
# 108.0    32503
# 123.0    27864
# 115.0    25174
#          ...
# 44.0         2
# 147.0        2
# 145.0        2
# 150.0        1
# 144.0        1
# Name: Po_SG_MVA, Length: 109, dtype: int64
#  63.0    30059
#  56.0    30003
#  52.0    29763
#  55.0    29050
#  59.0    28174
#          ...
# -14.0      196
# -19.0      140
# -17.0       99
# -18.0       96
# -21.0       68
# Name: Po_GFL_MVA, Length: 111, dtype: int64

# %%
for col in df.columns:
    df[col].value_counts().plot()

# %%
s = df['Total_MVA'].value_counts()
df2=df[df.isin(s.index[s >= 50]).values]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717116 entries, 0 to 717365
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Total_MVA   717116 non-null  float64
#  1   Po_GFM_MVA  717116 non-null  float64
#  2   Po_SG_MVA   717116 non-null  float64
#  3   Po_GFL_MVA  717116 non-null  float64
# dtypes: float64(4)
# memory usage: 27.4 MB

# %%
for col in df2.columns:
    print(df2[col].value_counts())
# Out:
# 178.0    100570
# 177.0     89512
# 176.0     59500
# 185.0     33280
# 175.0     32456
# 201.0     32262
# 193.0     31033
# 216.0     25975
# 208.0     25388
# 200.0     21120
# 209.0     19259
# 184.0     17557
# 174.0     16731
# 172.0     16230
# 192.0     16137
# 215.0     16121
# 186.0     15914
# 173.0     12357
# 199.0     10852
# 183.0      9691
# 194.0      9346
# 207.0      9237
# 202.0      8783
# 191.0      8619
# 214.0      8480
# 206.0      8342
# 217.0      6831
# 190.0      6148
# 198.0      6058
# 182.0      5246
# 179.0      4654
# 181.0      4262
# 189.0      4249
# 213.0      3826
# 205.0      2489
# 210.0      2444
# 180.0      2156
# 197.0      2048
# 188.0      1923
# 187.0      1468
# 203.0      1349
# 195.0      1233
# 218.0       996
# 171.0       962
# 211.0       890
# 204.0       654
# 196.0       597
# 212.0       490
# 219.0       467
# 220.0       236
# 221.0       166
# 170.0       129
# 222.0       110
# 169.0        85
# 223.0        78
# ...

# %%
df2['Po_GFM_MVA'].value_counts()
# Out:
# 67.0    38309
# 68.0    36154
# 63.0    28814
# 60.0    28464
# 55.0    27497
#         ...
# 85.0      633
# 83.0      308
# 80.0      223
# 81.0      186
# 84.0       77
# Name: Po_GFM_MVA, Length: 77, dtype: int64

# %%
df2['Po_SG_MVA'].value_counts()
# Out:
# 101.0    43076
# 94.0     39279
# 108.0    32494
# 123.0    27860
# 115.0    25172
#          ...
# 147.0        2
# 44.0         2
# 145.0        2
# 150.0        1
# 144.0        1
# Name: Po_SG_MVA, Length: 109, dtype: int64

# %%
ss=df2['Po_SG_MVA'].value_counts()
df3=df2[df2.isin(ss.index[ss >= 2]).values]

# %%
df3['Po_SG_MVA'].value_counts()
# Out:
# 101.0    89631
# 94.0     86519
# 108.0    66129
# 72.0     60246
# 57.0     58236
#          ...
# 141.0        6
# 44.0         6
# 145.0        4
# 147.0        4
# 144.0        1
# Name: Po_SG_MVA, Length: 108, dtype: int64

# %%
df2['Po_SG_MVA'].value_counts()
# Out:
# 101.0    43076
# 94.0     39279
# 108.0    32494
# 123.0    27860
# 115.0    25172
#          ...
# 147.0        2
# 44.0         2
# 145.0        2
# 150.0        1
# 144.0        1
# Name: Po_SG_MVA, Length: 109, dtype: int64

# %%
df2
# Out:
#         Total_MVA  Po_GFM_MVA  Po_SG_MVA  Po_GFL_MVA
# 0           172.0        69.0      123.0       -20.0
# 1           173.0        69.0      123.0       -20.0
# 2           172.0        69.0      123.0       -20.0
# 3           172.0        69.0      122.0       -20.0
# 4           173.0        69.0      123.0       -20.0
# ...           ...         ...        ...         ...
# 717361      184.0        56.0       41.0        88.0
# 717362      184.0        56.0       41.0        88.0
# 717363      184.0        56.0       41.0        88.0
# 717364      184.0        56.0       41.0        88.0
# 717365      184.0        56.0       41.0        88.0
#
# [717116 rows x 4 columns]

# %%
df
# Out:
#         Total_MVA  Po_GFM_MVA  Po_SG_MVA  Po_GFL_MVA
# 0           172.0        69.0      123.0       -20.0
# 1           173.0        69.0      123.0       -20.0
# 2           172.0        69.0      123.0       -20.0
# 3           172.0        69.0      122.0       -20.0
# 4           173.0        69.0      123.0       -20.0
# ...           ...         ...        ...         ...
# 717361      184.0        56.0       41.0        88.0
# 717362      184.0        56.0       41.0        88.0
# 717363      184.0        56.0       41.0        88.0
# 717364      184.0        56.0       41.0        88.0
# 717365      184.0        56.0       41.0        88.0
#
# [717366 rows x 4 columns]

# %%
col=['Total_MVA','Po_GFM_MVA','Po_SG_MVA','Po_GFL_MVA']
col_c=['countT','countGM','countS','countGL']
dfr=0
for i in range(4):
    dfr = pd.DataFrame(df[col[i]].value_counts())
    dfr.reset_index(inplace=True)
    dfr.columns = [col[i],col_c[i]]
    dfr = df.merge(dfr,on=col[i])
    df=dfr
    print(df)
# Out:
#         Total_MVA  Po_GFM_MVA  Po_SG_MVA  Po_GFL_MVA  countT
# 0           172.0        69.0      123.0       -20.0   16230
# 1           172.0        69.0      123.0       -20.0   16230
# 2           172.0        69.0      122.0       -20.0   16230
# 3           172.0        69.0      122.0       -20.0   16230
# 4           172.0        69.0      122.0       -20.0   16230
# ...           ...         ...        ...         ...     ...
# 717361      153.0        16.0       97.0        39.0       2
# 717362      232.0        56.0       91.0        85.0       4
# 717363      232.0        65.0       84.0        83.0       4
# 717364      232.0        64.0       83.0        85.0       4
# 717365      232.0        64.0       84.0        85.0       4
#
# [717366 rows x 5 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [26], line 8
# ...

# %%
# Out:
#         Total_MVA  Po_GFM_MVA  Po_SG_MVA  Po_GFL_MVA  countT
# 0           172.0        69.0      123.0       -20.0   16230
# 1           172.0        69.0      123.0       -20.0   16230
# 2           172.0        69.0      122.0       -20.0   16230
# 3           172.0        69.0      122.0       -20.0   16230
# 4           172.0        69.0      122.0       -20.0   16230
# ...           ...         ...        ...         ...     ...
# 717361      153.0        16.0       97.0        39.0       2
# 717362      232.0        56.0       91.0        85.0       4
# 717363      232.0        65.0       84.0        83.0       4
# 717364      232.0        64.0       83.0        85.0       4
# 717365      232.0        64.0       84.0        85.0       4
#
# [717366 rows x 5 columns]

# %%
dfn[dfn.countT>=50]
# Out:
#         Total_MVA  Po_GFM_MVA  Po_SG_MVA  Po_GFL_MVA  countT
# 0           172.0        69.0      123.0       -20.0   16230
# 1           172.0        69.0      123.0       -20.0   16230
# 2           172.0        69.0      122.0       -20.0   16230
# 3           172.0        69.0      122.0       -20.0   16230
# 4           172.0        69.0      122.0       -20.0   16230
# ...           ...         ...        ...         ...     ...
# 717216      183.0        56.0       40.0        87.0    9691
# 717217      183.0        56.0       40.0        87.0    9691
# 717218      183.0        56.0       40.0        87.0    9691
# 717219      183.0        56.0       40.0        88.0    9691
# 717220      183.0        56.0       40.0        88.0    9691
#
# [717116 rows x 5 columns]

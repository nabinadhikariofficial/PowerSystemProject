# %%
import pandas as pd

# %%
data=pd.read_csv('data/data_trunc.csv',index_col=0)

# %%
data
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976       50.0        50.0        50.0      123.0        69.0
# 1       19.986       50.0        50.0        50.0      123.0        69.0
# 2       19.996       50.0        50.0        50.0      123.0        69.0
# 3       20.016       50.0        50.0        50.0      122.0        69.0
# 4       20.026       50.0        50.0        50.0      123.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717361  49.924       50.0        50.0        50.0       41.0        56.0
# 717362  49.934       50.0        50.0        50.0       41.0        56.0
# 717363  49.944       50.0        50.0        50.0       41.0        56.0
# 717364  49.954       50.0        50.0        50.0       41.0        56.0
# 717365  49.964       50.0        50.0        50.0       41.0        56.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  Vo_GFL_PU  SCL_SG_MVA  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717366 entries, 0 to 717365
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         717366 non-null  float64
#  1   Fre_SG_Hz    717366 non-null  float64
#  2   Fre_GFM_Hz   717366 non-null  float64
#  3   Fre_GFL_Hz   717366 non-null  float64
#  4   Po_SG_MVA    717366 non-null  float64
#  5   Po_GFM_MVA   717366 non-null  float64
#  6   Po_GFL_MVA   717366 non-null  float64
#  7   Total_MVA    717366 non-null  float64
#  8   Vo_SG_PU     717366 non-null  float64
#  9   Vo_GFM_PU    717366 non-null  float64
#  10  Vo_GFL_PU    717366 non-null  float64
#  11  SCL_SG_MVA   717366 non-null  float64
#  12  SCL_GFM_MVA  717366 non-null  float64
#  13  SCL_GFL_MVA  717366 non-null  float64
# dtypes: float64(14)
# memory usage: 82.1 MB

# %%
df=data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717366 entries, 0 to 717365
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         717366 non-null  float64
#  1   Fre_SG_Hz    717366 non-null  float64
#  2   Fre_GFM_Hz   717366 non-null  float64
#  3   Fre_GFL_Hz   717366 non-null  float64
#  4   Po_SG_MVA    717366 non-null  float64
#  5   Po_GFM_MVA   717366 non-null  float64
#  6   Po_GFL_MVA   717366 non-null  float64
#  7   Total_MVA    717366 non-null  float64
#  8   Vo_SG_PU     717366 non-null  float64
#  9   Vo_GFM_PU    717366 non-null  float64
#  10  Vo_GFL_PU    717366 non-null  float64
#  11  SCL_SG_MVA   717366 non-null  float64
#  12  SCL_GFM_MVA  717366 non-null  float64
#  13  SCL_GFL_MVA  717366 non-null  float64
# dtypes: float64(14)
# memory usage: 82.1 MB

# %%
df.describe()
# Out:
#                 Time      Fre_SG_Hz     Fre_GFM_Hz     Fre_GFL_Hz  \
# count  717366.000000  717366.000000  717366.000000  717366.000000
# mean       35.027961      49.998138      49.998227      49.998531
# std         7.980724       0.015567       0.013588       0.010381
# min        19.972000      49.929000      49.915000      49.957000
# 25%        28.131000      49.998000      49.997000      49.997000
# 50%        35.199000      50.000000      50.000000      50.000000
# 75%        41.787000      50.000000      50.000000      50.000000
# max        49.965000      50.073000      50.083000      50.042000
#
#            Po_SG_MVA     Po_GFM_MVA     Po_GFL_MVA      Total_MVA  \
# count  717366.000000  717366.000000  717366.000000  717366.000000
# mean       91.200956      48.445338      48.714899     188.372732
# std        21.844904      17.903333      23.236615      13.831393
# min        39.000000      10.000000     -21.000000     153.000000
# ...

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# 26.483    200
# 26.453    200
# 28.992    200
# 28.962    200
# 28.952    200
#          ...
# 29.438      1
# 29.428      1
# 29.418      1
# 29.398      1
# 49.965      1
# Name: Time, Length: 15245, dtype: int64
# 50.000    326272
# 49.999     54324
# 50.001     37434
# 49.998     24272
# 49.997     15886
#            ...
# 50.059       153
# 50.062       138
# 50.061       135
# 50.060       132
# 50.073        48
# Name: Fre_SG_Hz, Length: 145, dtype: int64
# 50.000    273174
# 49.999     56887
# 50.001     39719
# 49.998     28810
# 49.997     19335
#            ...
# 49.918        12
# 49.917        11
# 50.083         4
# 49.915         2
# 49.916         2
# Name: Fre_GFM_Hz, Length: 169, dtype: int64
# 50.000    281501
# 49.999     55502
# 50.001     38468
# 49.998     28920
# 49.997     19960
#            ...
# 50.041       462
# 49.959       260
# 49.958        58
# 50.042        54
# 49.957        12
# Name: Fre_GFL_Hz, Length: 86, dtype: int64
# 101.0    43084
# ...

# %%
for col in df.columns:
    df[col].value_counts().plot()

# %%
col=['Total_MVA','Po_GFM_MVA','Po_SG_MVA','Po_GFL_MVA','Fre_SG_Hz','Fre_GFM_Hz', 'Fre_GFL_Hz', 'Vo_SG_PU','Vo_GFM_PU', 'Vo_GFL_PU']
col_c=['countT','countGM','countS','countGL','c5','c6','c7','c8','c9','c10']
dfr=0
for i in range(10):
    dfr = pd.DataFrame(df[col[i]].value_counts())
    dfr.reset_index(inplace=True)
    dfr.columns = [col[i],col_c[i]]
    dfr = df.merge(dfr,on=col[i])
    df=dfr
    print(df)
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976     50.000      50.000      50.000      123.0        69.0
# 1       19.996     50.000      50.000      50.000      123.0        69.0
# 2       20.016     50.000      50.000      50.000      122.0        69.0
# 3       20.036     50.000      50.000      50.000      122.0        69.0
# 4       20.056     50.000      50.000      50.000      122.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717361  40.027     50.005      50.027      50.008       97.0        16.0
# 717362  35.339     49.930      49.936      49.959       91.0        56.0
# 717363  25.363     49.930      49.937      49.958       84.0        65.0
# 717364  35.349     49.930      49.937      49.959       83.0        64.0
# 717365  45.344     49.930      49.937      49.959       84.0        64.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  Vo_GFL_PU  SCL_SG_MVA  \
# ...

# %%
df
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976     50.000      50.000      50.000      123.0        69.0
# 1       19.996     50.000      50.000      50.000      123.0        69.0
# 2       20.726     50.000      50.000      50.000      123.0        69.0
# 3       20.746     50.000      50.000      50.000      123.0        69.0
# 4       20.766     50.000      50.000      50.000      123.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717361  35.020     49.992      49.966      49.989       94.0        31.0
# 717362  35.020     49.992      49.966      49.989       94.0        74.0
# 717363  35.017     49.991      49.974      49.992       66.0        77.0
# 717364  30.022     50.008      50.034      50.009      117.0        38.0
# 717365  30.022     50.008      50.035      50.009      110.0        42.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  ...  countT  countGM  \
# ...

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# 26.493    200
# 26.443    200
# 26.413    200
# 26.483    200
# 26.423    200
#          ...
# 33.767      1
# 33.747      1
# 33.727      1
# 33.687      1
# 22.821      1
# Name: Time, Length: 15245, dtype: int64
# 50.000    326272
# 49.999     54324
# 50.001     37434
# 49.998     24272
# 49.997     15886
#            ...
# 50.059       153
# 50.062       138
# 50.061       135
# 50.060       132
# 50.073        48
# Name: Fre_SG_Hz, Length: 145, dtype: int64
# 50.000    273174
# 49.999     56887
# 50.001     39719
# 49.998     28810
# 49.997     19335
#            ...
# 49.918        12
# 49.917        11
# 50.083         4
# 49.916         2
# 49.915         2
# Name: Fre_GFM_Hz, Length: 169, dtype: int64
# 50.000    281501
# 49.999     55502
# 50.001     38468
# 49.998     28920
# 49.997     19960
#            ...
# 50.041       462
# 49.959       260
# 49.958        58
# 50.042        54
# 49.957        12
# Name: Fre_GFL_Hz, Length: 86, dtype: int64
# 101.0    43084
# ...

# %%
df2=df[df.countT>=50]
df3=df2[df2.countGM>=50]
df4=df3[df3.countS>=50]
df5=df4[df4.countGL>=50]
df6=df5[df5.c5>=50]
df7=df6[df6.c6>=50]
df8=df7[df7.c7>=50]
df9=df8[df8.c8>=50]
df10=df9[df9.c9>=50]
df11=df10[df10.c10>=50]

# %%
for col in df10.columns:
    print(df10[col].value_counts())
# Out:
# 26.413    200
# 28.982    200
# 26.423    200
# 26.473    200
# 26.493    200
#          ...
# 42.153      1
# 32.462      1
# 27.444      1
# 37.480      1
# 25.011      1
# Name: Time, Length: 15239, dtype: int64
# 50.000    326272
# 49.999     54312
# 50.001     37418
# 49.998     24249
# 49.997     15862
#            ...
# 50.063       180
# 50.059       152
# 50.061       135
# 50.062       135
# 50.060       131
# Name: Fre_SG_Hz, Length: 144, dtype: int64
# 50.000    273174
# 49.999     56887
# 50.001     39719
# 49.998     28810
# 49.997     19335
#            ...
# 50.077        54
# 49.920        51
# 49.932        50
# 50.081        49
# 49.930        46
# Name: Fre_GFM_Hz, Length: 148, dtype: int64
# 50.000    281501
# 49.999     55497
# 50.001     38453
# 49.998     28906
# 49.997     19943
#            ...
# 50.041       459
# 50.035       449
# 49.959       239
# 50.042        54
# 49.958        48
# Name: Fre_GFL_Hz, Length: 85, dtype: int64
# 101.0    43031
# ...

# %%
df11
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976     50.000      50.000      50.000      123.0        69.0
# 1       19.996     50.000      50.000      50.000      123.0        69.0
# 2       20.726     50.000      50.000      50.000      123.0        69.0
# 3       20.746     50.000      50.000      50.000      123.0        69.0
# 4       20.766     50.000      50.000      50.000      123.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717275  40.018     50.004      50.017      50.005      104.0        28.0
# 717276  40.017     50.004      50.015      50.004      101.0        28.0
# 717277  40.017     50.004      50.015      50.005      105.0        20.0
# 717278  40.017     50.004      50.016      50.004      109.0        32.0
# 717281  40.017     50.005      50.016      50.005       92.0        36.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  ...  countT  countGM  \
# ...

# %%
df11=df11[data.columns]

# %%
df11
# Out:
#           Time  Fre_SG_Hz  Fre_GFM_Hz  Fre_GFL_Hz  Po_SG_MVA  Po_GFM_MVA  \
# 0       19.976     50.000      50.000      50.000      123.0        69.0
# 1       19.996     50.000      50.000      50.000      123.0        69.0
# 2       20.726     50.000      50.000      50.000      123.0        69.0
# 3       20.746     50.000      50.000      50.000      123.0        69.0
# 4       20.766     50.000      50.000      50.000      123.0        69.0
# ...        ...        ...         ...         ...        ...         ...
# 717275  40.018     50.004      50.017      50.005      104.0        28.0
# 717276  40.017     50.004      50.015      50.004      101.0        28.0
# 717277  40.017     50.004      50.015      50.005      105.0        20.0
# 717278  40.017     50.004      50.016      50.004      109.0        32.0
# 717281  40.017     50.005      50.016      50.005       92.0        36.0
#
#         Po_GFL_MVA  Total_MVA  Vo_SG_PU  Vo_GFM_PU  Vo_GFL_PU  SCL_SG_MVA  \
# ...

# %%
df11.to_csv('data/data_trunc.csv')
